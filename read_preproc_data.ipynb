# %%
from nilearn import plotting, datasets
import nibabel as nib

# %%
img = nib.load("/scratch/ghn8/fmri_on_celeba/derivatives/1st_level_analysis/fwhm5/sub-01/train_run38_M1653_gt_fix.nii.gz")
plotting.plot_stat_map(img)

# %%
# this is the 3D matrix containing the brain image's data
vol = img.get_fdata()
vol.shape # a lot of the volume is zeros
# Out:
# (65, 77, 61)

# %%
mask = nib.load("/scratch/ghn8/fmri_on_celeba/derivatives/1st_level_analysis/aparc+aseg.nii.gz") # mask out where the brain is in the 3D volume
print(mask.get_fdata().shape)
plotting.plot_stat_map(mask)
# Out:
# (65, 77, 61)

# %%
data = vol[mask.get_fdata() > 0] # only the brain
print(data.shape)
# Out:
# (59835,)
