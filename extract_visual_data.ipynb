# %%
from nilearn import plotting, datasets
import nibabel as nib
# Out:
# /home/px48/storage/miniconda3/envs/braindecoding/lib/python3.9/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
img = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/fwhm5/sub-01/sub-01_ses-01_run-01_train_face_gt_fix.nii.gz")
plotting.plot_stat_map(img)

# %%
img = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/fwhm5/sub-01/test_run27_F1145_gt_fix.nii.gz")
plotting.plot_stat_map(img)

# %%
# this is the 3D matrix containing the brain image's data
vol = img.get_fdata()
vol.shape # a lot of the volume is zeros
# Out:
# (65, 77, 61)

# %%
atlas_img = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/atlas/Yeo2011_7Networks_MNI152_FreeSurferConformed1mm_LiberalMask.3mm.nii.gz")
mask = atlas_img.get_fdata()

# %%
plotting.plot_img(atlas_img)

# %%
new_vol = vol.copy()
new_vol[mask != 1] = 0
new_img = nib.Nifti1Image(new_vol, img.affine)
plotting.plot_img(new_img)

# %%
visual_data = vol[mask == 1] # pick out visual network
print(visual_data.shape)
# Out:
# (5317,)

# %%
visual_data
# Out:
# array([ 0.19460268, -0.25915986, -0.3918671 , ...,  0.53018385,
#         0.5387978 ,  0.01686129])
