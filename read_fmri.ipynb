# %%
from nilearn import plotting, datasets
import nibabel as nib
# Out:
# /home/px48/storage/miniconda3/envs/braindecoding/lib/python3.9/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
img = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/aparc+aseg.nii.gz")
plotting.plot_stat_map(img)

# %%
# this is the 4D matrix containing the brain image's data
vol = img.get_fdata()
vol.shape # a lot of the volume is zeros
# Out:
# (65, 77, 61)

# %%
mask = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/aparc+aseg.nii.gz") # mask out where the brain is in the 3D volume
print(mask.get_fdata().shape)
plotting.plot_stat_map(mask)
# Out:
# (65, 77, 61)

# %%
data = vol[mask.get_fdata() > 0] # only the brain
print(data.shape)
# Out:
# (59835,)

# %%
img = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/fwhm5/sub-01/train_run99_M4355_gt_fix.nii.gz")
plotting.plot_stat_map(img)

# this is the 4D matrix containing the brain image's data
vol = img.get_fdata()
vol.shape # a lot of the volume is zeros

mask = nib.load("/share/sablab/nfs04/data/fmri_on_celeba/derivatives/1st_level_analysis/aparc+aseg.nii.gz") # mask out where the brain is in the 3D volume
print(mask.get_fdata().shape)
plotting.plot_stat_map(mask)

data = vol[mask.get_fdata() > 0] # only the brain
print(data.shape)
# Out:
# (65, 77, 61)
# (59835,)
